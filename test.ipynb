# %%
import torch

# %%
torch.manual_seed(0)
x = torch.randn(5, 10, 5, 5)

# %%
x_mean = x.mean(dim=[-1, -2], keepdim=True)
x.shape, x_mean.shape, (x - x_mean).shape
# Out:
# (torch.Size([5, 10, 5, 5]),
#  torch.Size([5, 10, 1, 1]),
#  torch.Size([5, 10, 5, 5]))

# %%
# print(Ys[:, 0])
# Ys

# %%
# ys = Ys[:, 0]
# yb = Ys[:, 1]

# %%
# print(ys.shape, x_mean.shape, x.shape)

# %%
x = torch.tensor([1, 2, 4])
print(x.shape)
print(x)
x.repeat(5, 1)
# Out:
# torch.Size([3])
# tensor([1, 2, 4])
# tensor([[1, 2, 4],
#         [1, 2, 4],
#         [1, 2, 4],
#         [1, 2, 4],
#         [1, 2, 4]])

# %%
for i in range(10 - 1, -1, -1):
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
from src.model import Discriminator

# %%
des = Discriminator()
des
# Out:
# Discriminator(
#   (downscale): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (final_block): Sequential(
#     (0): ConvLayer(
#       (conv_layer): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): ConvLayer(
#       (conv_layer): Conv2d(512, 512, kernel_size=(4, 4), stride=(1, 1))
#     )
#     (3): LeakyReLU(negative_slope=0.2)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=512, out_features=1, bias=True)
#     (6): LeakyReLU(negative_slope=0.01)
#   )
#   (progblock): ModuleList(
#     (0): DBlock(
#       (block): Sequential(
#         (0): ConvLayer(
#           (conv_layer): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): ConvLayer(
#           (conv_layer): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (3): LeakyReLU(negative_slope=0.2)
# ...

# %%
x = torch.rand(1 ,3, 8, 8)
des(x, 1, 1).shape
# Out:
# x : torch.Size([1, 3, 8, 8])
# x_rgb torch.Size([1, 512, 8, 8])
# downscaled torch.Size([1, 3, 4, 4])
# downscaled_rgb torch.Size([1, 512, 4, 4])
# x_real torch.Size([1, 512, 4, 4])
# torch.Size([1, 512, 4, 4])
# torch.Size([1, 1])

# %%
from src.model import Generator

# %%
gen = Generator()

# %%
gen = Generator()
x = torch.randn(1, 512)
print(gen(x, 0,0.5).shape)
# Out:
# torch.Size([1, 3, 4, 4])
# torch.Size([1, 3, 4, 4])

# %%
gen
# Out:
# Generator(
#   (norm): PixelNorm()
#   (input_layer): InputLayer(
#     (mapping_net): MappingNet(
#       (map): Sequential(
#         (0): FCLayer(
#           (fc): Sequential(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#           )
#         )
#         (1): FCLayer(
#           (fc): Sequential(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#           )
#         )
#         (2): FCLayer(
#           (fc): Sequential(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#           )
#         )
#         (3): FCLayer(
#           (fc): Sequential(
#             (0): Linear(in_features=512, out_features=512, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#           )
#         )
#         (4): FCLayer(
#           (fc): Sequential(
# ...
